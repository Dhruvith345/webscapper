# %%
from bs4 import BeautifulSoup
import requests

# %%
ipl_page=requests.get('https://www.cricbuzz.com/cricket-series/2810/indian-premier-league-2019/stats')

# %%
ipl_page
# Out:
# <Response [200]>

# %%
soup1=BeautifulSoup(ipl_page.text,'html')

# %%
ipl_codes=soup1.find('select',class_='form-control cb-cursor-pointer ng-pristine ng-untouched ng-valid ng-not-empty',id_='seasons')

# %%
ipl_codes

# %%
a=open('values_data.txt')

# %%
text_data=a.read()

# %%
text_data
# Out:
# '<select class="form-control cb-cursor-pointer ng-valid ng-not-empty ng-dirty ng-valid-parse ng-touched" id="seasons" ng-model="selectedSeason" ng-change="setSeason()"> <!-- ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="All" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">All Series</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="5945" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2023</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="4061" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2022</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="3472" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2021</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="3130" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2020</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2810" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope" selected="selected">IPL 2019</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2676" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2018</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2568" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2017</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2430" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2016</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2330" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2015</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2261" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2014</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2170" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2013</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2115" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2012</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2037" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2011</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2060" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2010</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2059" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2009</option><!-- end ngRepeat: season in seasons --><option ng-repeat="season in seasons" value="2058" ng-bind-html="season[\'shortName\']" class="ng-binding ng-scope">IPL 2008</option><!-- end ngRepeat: season in seasons --> </select>'

# %%
import re

# %%
pattern=r'\d{4}'

# %%
ipl_codesandyears=re.findall(pattern,text_data)

# %%
ipl_code_dict=dict()
for i in range(0,len(ipl_codesandyears),2):
  ipl_code_dict[ipl_codesandyears[i+1]]=ipl_codesandyears[i]

# %%
for i in list(ipl_code_dict.keys()):
  if int(i)<2014:
    del ipl_code_dict[i]

# %%
years=list(ipl_code_dict.keys())
values=list(ipl_code_dict.values())

# %%
years
# Out:
# ['2023',
#  '2022',
#  '2021',
#  '2020',
#  '2019',
#  '2018',
#  '2017',
#  '2016',
#  '2015',
#  '2014']

# %%
values
# Out:
# ['5945',
#  '4061',
#  '3472',
#  '3130',
#  '2810',
#  '2676',
#  '2568',
#  '2430',
#  '2330',
#  '2261']

# %%
list_0f_df=[]
for k in range(len(ipl_code_dict)):
  ipl_scoreboard=(requests.get("https://www.cricbuzz.com/cricket-series/"+
                                     values[k]+"/indian-premier-league-"+years[k]+"/points-table"))
  scr_brd=BeautifulSoup(ipl_scoreboard.text,'html')
  scr_brd_tble=scr_brd.find('table',class_='table cb-srs-pnts')
  other_data=scr_brd_tble.find_all('td',class_="cb-srs-pnts-td")
  entire_data=[data.text for data in other_data]
  names=scr_brd_tble.find_all('td',class_='cb-srs-pnts-name')
  teams=[name_data.text for name_data in names]
  cols=scr_brd_tble.find_all('td',class_='cb-srs-pnts-th')
  columns=[data.text for data in cols]
  columns.append('Teams')
  columns=columns[-1:]+columns[:-1]
  columns.append('points')
  columns[-2],columns[-1]=columns[-1],columns[-2]
  df=pd.DataFrame(columns=columns)
  df['Teams']=teams
  j=0
  for i in range(len(teams)):
    ind=1
    while(1):
      df.iloc[i,ind]=entire_data[j]
      try:
        int(entire_data[j])
      except:
        j+=1
        break
      j+=1
      ind+=1
  list_0f_df.append(df)

# %%
list_0f_df=list_0f_df[::-1]
years=years[::-1]
for dfs in range(len(list_0f_df)):
  print("Year",years[dfs],"\n")
  display(list_0f_df[dfs])
  print("\n")
# Out:
# Year 2014
#                          Teams Mat Won Lost Tied NR points     NRR
# 0                 Punjab Kings  14  11    3    0  0     22  +0.968
# 1        Kolkata Knight Riders  14   9    5    0  0     18  +0.418
# 2          Chennai Super Kings  14   9    5    0  0     18  +0.385
# 3               Mumbai Indians  14   7    7    0  0     14  +0.095
# 4             Rajasthan Royals  14   7    7    0  0     14  +0.060
# 5          Sunrisers Hyderabad  14   6    8    0  0     12  -0.399
# 6  Royal Challengers Bengaluru  14   5    9    0  0     10  -0.428
# 7               Delhi Capitals  14   2   12    0  0      4  -1.182
# Year 2015
#                          Teams Mat Won Lost Tied NR points     NRR
# 0          Chennai Super Kings  14   9    5    0  0     18  +0.709
# 1  Royal Challengers Bengaluru  14   7    5    0  2     16  +1.037
# 2             Rajasthan Royals  14   7    5    0  2     16  +0.062
# 3               Mumbai Indians  14   8    6    0  0     16  -0.043
# 4        Kolkata Knight Riders  14   7    6    0  1     15  +0.253
# 5          Sunrisers Hyderabad  14   7    7    0  0     14  -0.239
# 6               Delhi Capitals  14   5    8    0  1     11  -0.049
# 7                 Punjab Kings  14   3   11    0  0      6  -1.436
# Year 2016
#                          Teams Mat Won Lost Tied NR points     NRR
# 0                Gujarat Lions  14   9    5    0  0     18  -0.374
# 1  Royal Challengers Bengaluru  14   8    6    0  0     16  +0.932
# 2          Sunrisers Hyderabad  14   8    6    0  0     16  +0.245
# 3        Kolkata Knight Riders  14   8    6    0  0     16  +0.106
# 4               Mumbai Indians  14   7    7    0  0     14  -0.146
# 5               Delhi Capitals  14   7    7    0  0     14  -0.155
# 6       Rising Pune Supergiant  14   5    9    0  0     10  +0.015
# 7                 Punjab Kings  14   4   10    0  0      8  -0.646
# Year 2017
#                          Teams Mat Won Lost Tied NR points     NRR
# 0               Mumbai Indians  14  10    4    0  0     20  +0.784
# 1       Rising Pune Supergiant  14   9    5    0  0     18  +0.176
# 2          Sunrisers Hyderabad  14   8    5    0  1     17  +0.599
# 3        Kolkata Knight Riders  14   8    6    0  0     16  +0.641
# 4                 Punjab Kings  14   7    7    0  0     14  -0.009
# 5               Delhi Capitals  14   6    8    0  0     12  -0.512
# 6                Gujarat Lions  14   4   10    0  0      8  -0.412
# 7  Royal Challengers Bengaluru  14   3   10    0  1      7  -1.299
# Year 2018
#                          Teams Mat Won Lost Tied NR points     NRR
# 0          Sunrisers Hyderabad  14   9    5    0  0     18  +0.284
# 1          Chennai Super Kings  14   9    5    0  0     18  +0.253
# 2        Kolkata Knight Riders  14   8    6    0  0     16  -0.070
# 3             Rajasthan Royals  14   7    7    0  0     14  -0.250
# 4               Mumbai Indians  14   6    8    0  0     12  +0.317
# 5  Royal Challengers Bengaluru  14   6    8    0  0     12  +0.129
# 6                 Punjab Kings  14   6    8    0  0     12  -0.502
# 7               Delhi Capitals  14   5    9    0  0     10  -0.222
# Year 2019
#                          Teams Mat Won Lost Tied NR points     NRR
# 0               Mumbai Indians  14   9    5    0  0     18  +0.421
# 1          Chennai Super Kings  14   9    5    0  0     18  +0.131
# 2               Delhi Capitals  14   9    5    0  0     18  +0.044
# 3          Sunrisers Hyderabad  14   6    8    0  0     12  +0.577
# 4        Kolkata Knight Riders  14   6    8    0  0     12  +0.028
# 5                 Punjab Kings  14   6    8    0  0     12  -0.251
# 6             Rajasthan Royals  14   5    8    0  1     11  -0.449
# 7  Royal Challengers Bengaluru  14   5    8    0  1     11  -0.607
# Year 2020
#                          Teams Mat Won Lost Tied NR points     NRR
# 0               Mumbai Indians  14   9    5    0  0     18  +1.107
# 1               Delhi Capitals  14   8    6    0  0     16  -0.109
# 2          Sunrisers Hyderabad  14   7    7    0  0     14  +0.608
# 3  Royal Challengers Bengaluru  14   7    7    0  0     14  -0.172
# 4        Kolkata Knight Riders  14   7    7    0  0     14  -0.214
# 5                 Punjab Kings  14   6    8    0  0     12  -0.162
# 6          Chennai Super Kings  14   6    8    0  0     12  -0.455
# 7             Rajasthan Royals  14   6    8    0  0     12  -0.569
# Year 2021
#                          Teams Mat Won Lost Tied NR points     NRR
# 0          Delhi Capitals  (Q)  14  10    4    0  0     20  +0.481
# 1          Chennai Super Kings  14   9    5    0  0     18  +0.455
# 2  Royal Challengers Bengaluru  14   9    5    0  0     18  -0.140
# 3        Kolkata Knight Riders  14   7    7    0  0     14  +0.587
# 4               Mumbai Indians  14   7    7    0  0     14  +0.116
# 5                 Punjab Kings  14   6    8    0  0     12  -0.001
# 6             Rajasthan Royals  14   5    9    0  0     10  -0.993
# 7     Sunrisers Hyderabad  (E)  14   3   11    0  0      6  -0.545
# Year 2022
#                               Teams Mat Won Lost Tied NR points     NRR
# 0               Gujarat Titans  (Q)  14  10    4    0  0     20  +0.316
# 1             Rajasthan Royals  (Q)  14   9    5    0  0     18  +0.298
# 2         Lucknow Super Giants  (Q)  14   9    5    0  0     18  +0.251
# 3  Royal Challengers Bengaluru  (Q)  14   8    6    0  0     16  -0.253
# 4               Delhi Capitals  (E)  14   7    7    0  0     14  +0.204
# 5                 Punjab Kings  (E)  14   7    7    0  0     14  +0.126
# 6        Kolkata Knight Riders  (E)  14   6    8    0  0     12  +0.146
# 7          Sunrisers Hyderabad  (E)  14   6    8    0  0     12  -0.379
# 8          Chennai Super Kings  (E)  14   4   10    0  0      8  -0.203
# 9               Mumbai Indians  (E)  14   4   10    0  0      8  -0.506
# Year 2023
#                               Teams Mat Won Lost Tied NR points     NRR
# 0               Gujarat Titans  (Q)  14  10    4    0  0     20  +0.809
# 1          Chennai Super Kings  (Q)  14   8    5    0  1     17  +0.652
# 2         Lucknow Super Giants  (Q)  14   8    5    0  1     17  +0.284
# 3               Mumbai Indians  (Q)  14   8    6    0  0     16  -0.044
# 4             Rajasthan Royals  (E)  14   7    7    0  0     14  +0.148
# 5  Royal Challengers Bengaluru  (E)  14   7    7    0  0     14  +0.135
# 6        Kolkata Knight Riders  (E)  14   6    8    0  0     12  -0.239
# 7                 Punjab Kings  (E)  14   6    8    0  0     12  -0.304
# 8               Delhi Capitals  (E)  14   5    9    0  0     10  -0.808
# 9          Sunrisers Hyderabad  (E)  14   4   10    0  0      8  -0.590
